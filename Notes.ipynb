# %% [markdown]
# ## Notes

# %% [markdown]
# ### (from -r requirements.txt (line 21)) does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# ![image.png](attachment:01ff96b4-0d5e-4f2c-a9c3-c0b445cf2204.png)

# %% [markdown]
# ![image.png](attachment:09bc0f57-5d08-4c58-8aec-d3f74c688d77.png)

# %% [markdown]
# ![image.png](attachment:5f0cd4fe-ab4e-445f-9a50-5ec8261aa171.png)

# %% [markdown]
# ### -e what is this?

# %% [markdown]
# ![image.png](attachment:1520ba90-1e73-4c00-8367-215662b4a2ed.png)

# %% [markdown]
# ![image.png](attachment:ce6d28ea-9f66-4c13-8e84-70f69c044a9c.png)

# %% [markdown]
# ### as a python package means?

# %% [markdown]
# ![image.png](attachment:bf7a0419-9779-44d6-bb42-563d097c5921.png)

# %% [markdown]
# ![image.png](attachment:4ce60eb5-3bdf-43dc-82ab-41d63aa48f70.png)

# %% [markdown]
# ![image.png](attachment:f7a8fb02-fb21-435a-a2ad-bb2d6756d922.png)

# %% [markdown]
# ![image.png](attachment:7accb69d-0914-4426-bb4d-5536e0e7db4a.png)

# %% [markdown]
# ### what is inplace

# %% [markdown]
# so that the changes will take place in the same place where our dataset is

# %% [markdown]
# ### json.loads

# %% [markdown]
# helps to convert python object to json

# %%
import pandas as pd
data=pd.read_csv(r"C:\datascience Files\projects2\aps-fault-detection-main\aps_failure_training_set1.csv")
print(data.head())
# Out:
#   class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000  ag_001   ag_002  \
# 0   pos  153204      0    182     na      0      0      0       0        0
# 1   pos  453236     na   2926     na      0      0      0       0      222
# 2   pos   72504     na   1594   1052      0      0      0     244   178226
# 3   pos  762958     na     na     na     na     na    776  281128  2186308
# 4   pos  695994     na     na     na     na     na      0       0        0
#
#    ...   ee_002   ee_003   ee_004   ee_005   ee_006  ee_007  ee_008 ee_009  \
# 0  ...   129862    26872    34044    22472    34362       0       0      0
# 1  ...  7908038  3026002  5025350  2025766  1160638  533834  493800   6914
# 2  ...  1432098   372252   527514   358274   332818  284178    3742      0
# 3  ...       na       na       na       na       na      na      na     na
# 4  ...  1397742   495544   361646    28610     5130     212       0      0
#
#   ef_000 eg_000
# 0      0      0
# 1      0      0
# ...

# %% [markdown]
# ### Installing Requirements.txt File

# %% [markdown]
# ![image.png](attachment:38bd7df4-28bf-4046-b8d1-255515dc39f8.png)

# %% [markdown]
# ![image.png](attachment:93ed01e9-5abe-4136-96f9-41144f8082a3.png)

# %% [markdown]
# ![image.png](attachment:e03277a8-af8d-4511-bce3-8a5c088f95e2.png)

# %% [markdown]
# ### Error in installing Venv

# %% [markdown]
# ![image.png](attachment:e08b9f97-4d59-4173-873d-b27f158bae5b.png)

# %% [markdown]
# ![image.png](attachment:b61d8895-4a3e-41be-a022-57ae94f3c7eb.png)

# %% [markdown]
# ![image.png](attachment:d3f08540-057c-49fe-ae6c-08b1e97c80b2.png)

# %% [markdown]
# ### Venv (Virtual Environment)

# %% [markdown]
# #### Is it imporatant to make venv that is virtual environment for a project?

# %% [markdown]
# ![image.png](attachment:7b3165a5-c133-4a0b-9fca-f974af5835a6.png)

# %% [markdown]
# ![image.png](attachment:8f113ca4-7983-4f70-a7f7-8ca6e68c8620.png)

# %% [markdown]
# ![image.png](attachment:18b77eba-ad75-4a2c-b20a-36ad89be2c60.png)

# %% [markdown]
# #### what is a need to activate it?

# %% [markdown]
# ![image.png](attachment:9adf768a-093f-4e14-ab4c-8cd3a3dc41f2.png)

# %% [markdown]
# ![image.png](attachment:96f3f0f8-97f7-49c5-b145-577b96ab3658.png)

# %% [markdown]
# ![image.png](attachment:7aab60a3-e5b5-411d-83e1-86a830e714e0.png)

# %% [markdown]
# ![image.png](attachment:a7f62906-9c73-4f8f-b40c-8edef07b8660.png)

# %% [markdown]
# #### so if I am making another project that if I am not making venv so it will use global python directly?

# %% [markdown]
# ![image.png](attachment:e9a9058b-38c6-42cd-ae3f-f8f5201324b8.png)

# %% [markdown]
# ![image.png](attachment:ba7880a4-ea7f-40c7-80b3-d5e2a903cd23.png)

# %% [markdown]
# ![image.png](attachment:0c856f66-4225-43f3-9776-342108eb538d.png)

# %% [markdown]
# ### Successfully Installed requirements.txt file

# %% [markdown]
# remove line httptools and apache-airflow from requirements.txt

# %% [markdown]
# ### MongoDB atlas Connection

# %% [markdown]
# use without SRV url link

# %% [markdown]
# ![image.png](attachment:c430d9dd-4ced-4255-91dd-b2fc7ee7978a.png)

# %% [markdown]
# ### ctrl v is not working in terminal of vscode

# %% [markdown]
# shift + insert

# %% [markdown]
# ### MongoDB Related

# %% [markdown]
# #### how to get a localhost url for mongodb

# %% [markdown]
# ![image.png](attachment:571e7895-bb2b-4318-9cfd-1d89ca11039c.png)

# %% [markdown]
# #### what if I will directly write url like this uri = f"mongodb+srv://{username}:{password}@cluster0.c08uesf.mongodb.net/?appName=Cluster0"

# %% [markdown]
# ![image.png](attachment:679a46bc-8321-442d-9cee-02ca85fa7be6.png)

# %% [markdown]
# #### but I am making ML project

# %% [markdown]
# ![image.png](attachment:a7368206-e99a-4be4-bc5b-e34e608601e2.png)

# %% [markdown]
# #### but this project I will include in resume also

# %% [markdown]
# ![image.png](attachment:ede708a3-f1f9-4d27-b478-aa8f5608f557.png)

# %% [markdown]
# #### sir had used localhost

# %% [markdown]
# ![image.png](attachment:9e46f808-948d-4405-8f83-81802f89a034.png)

# %% [markdown]
# ![image.png](attachment:ccbd0473-6e47-447e-9afb-8dbe3cc2cf10.png)

# %% [markdown]
# #### MongoDB Password Related

# %% [markdown]
# ![image.png](attachment:9ed9b413-58a4-4374-88dc-450600d94a63.png)

# %% [markdown]
# ![image.png](attachment:55c826da-ac7e-47e6-997d-be95b664806e.png)

# %% [markdown]
# #### i think that is why sir had not used atlas cuz then he had to share password also

# %% [markdown]
# ![image.png](attachment:40056470-3ff8-410e-8546-7f1fdc6047f2.png)

# %% [markdown]
# ![image.png](attachment:239b39a4-3445-4395-b958-de6de2f4c4eb.png)

# %% [markdown]
# #### so what I should do now?

# %% [markdown]
# ![image.png](attachment:84d95d87-96a8-4466-83bc-0c7c9061ff04.png)

# %% [markdown]
# import os
#
# uri = f"mongodb+srv://{os.getenv('MONGO_USER')}:{os.getenv('MONGO_PASS')}@cluster0.c08uesf.mongodb.net/aps_fault_detection?retryWrites=true&w=majority"

# %% [markdown]
# ![image.png](attachment:35fe19a6-7cca-4284-a228-b65b5c759083.png)

# %% [markdown]
# #### Interview

# %% [markdown]
# ![image.png](attachment:aefbd53d-d8df-4e69-9172-1502679bbc14.png)

# %% [markdown]
# ### .env File

# %% [markdown]
# #### ok so help me in making .env file

# %% [markdown]
# ![image.png](attachment:113ac838-5418-411b-b9da-e86e18d0fec5.png)

# %% [markdown]
# ![image.png](attachment:984e1583-f32c-43e7-84d4-afbb74e39bad.png)

# %% [markdown]
# ![image.png](attachment:f94f6393-b432-405e-accc-56f128effbd5.png)

# %% [markdown]
# ![image.png](attachment:7dc621d2-d792-45cc-9594-8646ba887252.png)

# %% [markdown]
# ![image.png](attachment:1620e095-d64b-4024-9f4a-0f3ba6bb14e8.png)

# %% [markdown]
# #### what is dotenv library?

# %% [markdown]
# ![image.png](attachment:3abd4b4e-6891-43bc-bade-b5d6a57dfed1.png)

# %% [markdown]
# ![image.png](attachment:4c30e40b-f4f7-4aeb-ba22-e14d3b46027b.png)

# %% [markdown]
# ![image.png](attachment:0a8c7af0-86d6-4164-b6a7-694f5ee52435.png)

# %% [markdown]
# #### what .gitignore does?

# %% [markdown]
# ![image.png](attachment:aa1c1105-d30d-457f-8a4e-2f68944744d0.png)

# %% [markdown]
# ![image.png](attachment:6608d1bd-855e-40d2-9654-6c13c2635166.png)

# %% [markdown]
# #### so I will a person share .env file then

# %% [markdown]
# ![image.png](attachment:35cb2b35-5750-4253-b7d6-0d4ffd40bb87.png)

# %% [markdown]
# ![image.png](attachment:f65df8ea-f084-4833-aa6a-6e75ba4d8496.png)

# %% [markdown]
# ### Github

# %% [markdown]
# #### Just tell me the steps to add my project to github repo

# %% [markdown]
# ![image.png](attachment:a82b8518-9051-45fb-b0b2-cce07b568473.png)

# %% [markdown]
# ![image.png](attachment:2054d9ac-d85e-4ec5-a27a-ebaf29f0a4b3.png)

# %% [markdown]
# ![image.png](attachment:7bce58c7-8b08-4631-bd67-eceeff38b66b.png)

# %% [markdown]
# #### how to know whether my branch is main in vscode before Push your code to GitHub

# %% [markdown]
# ![image.png](attachment:98cb6456-68b1-4dd0-8308-edca849ffa60.png)

# %% [markdown]
# it is showing * master

# %% [markdown]
# ![image.png](attachment:1bb25efc-364f-482b-a6ee-feca1c6f6863.png)

# %% [markdown]
# #### Error

# %% [markdown]
# ![image.png](attachment:45554e34-3585-402b-8d89-2699ad37a62e.png)

# %% [markdown]
# ![image.png](attachment:e86d6c78-25ed-464a-a58f-76cea1f272f3.png)

# %% [markdown]
# #### how to save it because it is showing please enter a commit message after I wrote git pull origin main --allow-unrelated-histories

# %% [markdown]
# ![image.png](attachment:2f287d36-7ecc-4e70-a3b1-787060f4e8c1.png)

# %% [markdown]
# ![image.png](attachment:0637f526-1645-4280-8692-72aa80c248f3.png)

# %% [markdown]
# #### where is : Go to command line mode (bottom of screen)

# %% [markdown]
# ![image.png](attachment:fa01f1b4-67a9-498c-8a71-9e2abcbe6674.png)

# %% [markdown]
# ![image.png](attachment:a471917b-b1a2-4f78-9739-8da997de3c37.png)

# %% [markdown]
# #### do you think this is it to learn in github?

# %% [markdown]
# ![image.png](attachment:7d33fbbb-dcec-4da4-953e-224f6ca050ed.png)
# ![image.png](attachment:6f363e9e-23c9-490d-ad43-b82a60bc0ec8.png)#%% md
# ![image.png](attachment:bf1d8216-7b1c-4b57-8cac-573b3c538a75.png)

# %% [markdown]
# ![image.png](attachment:16db3229-589b-4a78-b011-827dc364472e.png)

# %% [markdown]
# ![image.png](attachment:8535ef8e-df09-48f1-9c46-32af7aa08c63.png)

# %% [markdown]
# #### give me a pointers that I Learned in a github and what I should learn later?

# %% [markdown]
# ![image.png](attachment:ad7e5461-06b0-4284-8c92-a0b6e71fac5e.png)

# %% [markdown]
# ![image.png](attachment:397ed636-0b92-4ced-adcf-fdda4ab8f018.png)

# %% [markdown]
# ![image.png](attachment:7d4796a2-ce3e-4606-9847-88895adfc6ef.png)

# %% [markdown]
# ![image.png](attachment:259e5b81-98c1-412f-9c21-2690a60fac99.png)

# %% [markdown]
# ![image.png](attachment:bf4170ff-8ab2-4bab-b23f-8369605276b1.png)

# %% [markdown]
# ### -e.  ?

# %% [markdown]
# ![image.png](attachment:72de4aad-450a-43f3-ac61-bdc8526e341a.png)

# %% [markdown]
# ![image.png](attachment:5fa49377-1045-4e7b-bb1b-98df037458eb.png)

# %% [markdown]
# #### does that mean that if I will run my project in another system I do not need to reinstall libraries?

# %% [markdown]
# ![image.png](attachment:0218a73c-d84d-4741-85d3-a313dc32ef15.png)

# %% [markdown]
# ![image.png](attachment:55791d99-d0cd-4b73-b74f-9520c778e367.png)

# %% [markdown]
# #### but what is the relation between changing code and re installing libraries?

# %% [markdown]
# ![image.png](attachment:77e46e2a-bea4-40e0-9c20-27f3940e7e95.png)

# %% [markdown]
# ![image.png](attachment:816a3138-3638-45c1-813c-3be4ffcc1c76.png)

# %% [markdown]
# ![image.png](attachment:1d4d7467-5e5f-46a2-bfcc-13464b1cbce9.png)

# %% [markdown]
# #### for example if I install requirements.txt and I write some code than I install some other library directly from terminal so it will directly get updated inside the requirements.txt file, is it like that?

# %% [markdown]
# ![image.png](attachment:aa144146-dcd9-4c6e-a566-5ab96efaa592.png)

# %% [markdown]
# ![image.png](attachment:dc02cbc4-784b-4637-be48-55976cbb949c.png)

# %% [markdown]
# #### With -e . (editable mode) , You change your code → Python automatically reads the updated code → No need to reinstall,Python automatically reads the updated code means? what is the need of it?

# %% [markdown]
# ![image.png](attachment:7386b5fd-9a53-449a-b5e4-4610211d47cf.png)

# %% [markdown]
# ![image.png](attachment:2b1ef5c4-bda7-4547-bc22-4457ccdf2b68.png)

# %% [markdown]
# ![image.png](attachment:4966994c-b95d-4238-9f3f-3d4c763d7b69.png)

# %% [markdown]
# #### so it is basically something for codes not for libraries.

# %% [markdown]
# ![image.png](attachment:96d6c19b-c8e8-4cc4-a2d8-869aa8fad732.png)

# %% [markdown]
# ![image.png](attachment:9eb0bf93-f1a5-4d69-bf31-8ee34a8f808c.png)

# %% [markdown]
# #### where does it reflects?

# %% [markdown]
# ![image.png](attachment:5e7db618-ab7f-4c1d-8efc-d1bccf8233ef.png)

# %% [markdown]
# ![image.png](attachment:6dc65b06-68ed-43ce-835f-9e3f2176df59.png)

# %% [markdown]
# ![image.png](attachment:0fc609f9-8e91-4f5e-8f13-e6d6aac07d37.png)

# %% [markdown]
# #### so basically it helps in development process if we make some changes in the code and modify it

# %% [markdown]
# ![image.png](attachment:541134f1-b5f5-4862-a2de-779c4fac2668.png)

# %% [markdown]
# ![image.png](attachment:4a97f199-4b05-4aa5-a38f-07b29fb7913a.png)

# %% [markdown]
# #### installing a project means importing it as a library you mean to say, right?

# %% [markdown]
# ![image.png](attachment:fed943f6-3d58-4d7a-a2aa-1e1b27fa6f3e.png)

# %% [markdown]
# ![image.png](attachment:e8437263-3ad9-4bd0-9e97-314dfce40b47.png)

# %% [markdown]
# ![image.png](attachment:71d8ec80-4ea2-4f97-8d5f-97c0a3e13641.png)
